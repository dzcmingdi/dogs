# %%
from shutil import copy2
import os
def create_file():
    import os
    path_all = []
    for path in os.listdir('C:/Users/10194/Desktop/dog_data/dog_data'):
        path_all.append(path)

    file_path = os.path.abspath('data/dog_data')
    for path in path_all:
        for imgpath in os.listdir(os.path.join('C:/Users/10194/Desktop/dog_data/dog_data' + '/' + path)):
            fileName = os.path.join('C:/Users/10194/Desktop/dog_data/dog_data' + '/' +path, imgpath)
            old = 'C:/Users/10194/Desktop/dog_data/dog_data' + '/' + path + '/' + imgpath
            new = file_path + '/' + path
            copy2(old, new)
            print(old)
            print(new)
            break
        
create_file()
# Out:
# C:/Users/10194/Desktop/dog_data/dog_data/n02085620-Chihuahua/n02085620-Chihuahua.txt
# c:\Users\10194\Desktop\IE11305\data\dog_data/n02085620-Chihuahua
# C:/Users/10194/Desktop/dog_data/dog_data/n02085782-Japanese_spaniel/n02085782-Japanese_spaniel.txt
# c:\Users\10194\Desktop\IE11305\data\dog_data/n02085782-Japanese_spaniel
# C:/Users/10194/Desktop/dog_data/dog_data/n02085936-Maltese_dog/n02085936-Maltese_dog.txt
# c:\Users\10194\Desktop\IE11305\data\dog_data/n02085936-Maltese_dog
# C:/Users/10194/Desktop/dog_data/dog_data/n02086079-Pekinese/n02086079-Pekinese.txt
# c:\Users\10194\Desktop\IE11305\data\dog_data/n02086079-Pekinese
# C:/Users/10194/Desktop/dog_data/dog_data/n02086240-Shih-Tzu/n02086240-Shih-Tzu.txt
# c:\Users\10194\Desktop\IE11305\data\dog_data/n02086240-Shih-Tzu
# C:/Users/10194/Desktop/dog_data/dog_data/n02086646-Blenheim_spaniel/n02086646-Blenheim_spaniel.txt
# c:\Users\10194\Desktop\IE11305\data\dog_data/n02086646-Blenheim_spaniel
# ...
